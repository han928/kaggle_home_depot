# %%
from __future__ import division
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import zipfile, StringIO, requests
from sklearn.linear_model import LogisticRegression
from sklearn.cross_validation import train_test_split, cross_val_score
from sklearn.feature_extraction.text import TfidfVectorizer
import re
from sklearn.ensemble import RandomForestRegressor
import nltk.tokenize as tk
from nltk.corpus import stopwords
stopwords = stopwords.words('english')
from nltk.stem.snowball import SnowballStemmer
stemmer = SnowballStemmer('english')
from nltk.stem.wordnet import WordNetLemmatizer
wordnet = WordNetLemmatizer()

# %pylab inline
# Out:
# Populating the interactive namespace from numpy and matplotlib
# /home/han/anaconda2/lib/python2.7/site-packages/matplotlib/__init__.py:872: UserWarning: axes.color_cycle is deprecated and replaced with axes.prop_cycle; please use the latter.
#   warnings.warn(self.msg_depr % (key, alt_key))

# %%
z = zipfile.ZipFile('data/train_home_depot.zip')
df = pd.read_csv(z.open('train.csv'))

# %%
z2 = zipfile.ZipFile('data/attributes.csv.zip')
df_attributes = pd.read_csv(z2.open('attributes.csv'))

# %%
z3 = zipfile.ZipFile('data/product_descriptions.csv.zip')
df_description = pd.read_csv(z3.open('product_descriptions.csv'))

# %%
df_description['product_description'][0]
# Out:
# 'Not only do angles make joints stronger, they also provide more consistent, straight corners. Simpson Strong-Tie offers a wide variety of angles in various sizes and thicknesses to handle light-duty jobs or projects where a structural connection is needed. Some can be bent (skewed) to match the project. For outdoor projects or those where moisture is present, use our ZMAX zinc-coated connectors, which provide extra resistance against corrosion (look for a "Z" at the end of the model number).Versatile connector for various 90 connections and home repair projectsStronger than angled nailing or screw fastening aloneHelp ensure joints are consistently straight and strongDimensions: 3 in. x 3 in. x 1-1/2 in.Made from 12-Gauge steelGalvanized for extra corrosion resistanceInstall with 10d common nails or #9 x 1-1/2 in. Strong-Drive SD screws'

# %% [markdown]
# ## Things to do
# * featurize product title, product description and product attributes
# *

# %%
df['searchfix'] = df['search_term'].str.lower().str.decode('ISO-8859-1').str.encode('ascii', 'ignore').str.split()\
.apply(lambda x: [stemmer.stem(item) for item in x]) \
.apply(lambda x: [wordnet.lemmatize(item) for item in x])

# %%
df.tail()
# Out:
#            id  product_uid                                      product_title  \
# 74062  221457       206638  Atlantic Windowpane 576 CD or 192 DVD Blu-Ray ...
# 74063  221458       206639  Philips 40-Watt Halogen R20 Flood Light Bulb (...
# 74064  221463       206641  Schlage Camelot In-Active Aged Bronze Handlese...
# 74065  221471       206648  Plastec 11 in. x 24 in. Rose Garden Wall Decor...
# 74066  221473       206650  LICHTENBERG Pool Blue No. 918 Millennial Ryan ...
#
#                                    search_term  relevance  \
# 74062                           tv riser glass       1.00
# 74063                        r20 halogen light       3.00
# 74064  schlage lock siena half dummy knob with       2.33
# 74065                        zen garden  decor       3.00
# 74066             fine sheer curtain 63 inches       2.33
#
#                                              searchfix
# 74062                               [tv, riser, glass]
# 74063                            [r20, halogen, light]
# 74064  [schlage, lock, siena, half, dummi, knob, with]
# 74065                             [zen, garden, decor]
# 74066                 [fine, sheer, curtain, 63, inch]

# %%
df['titlefix'] = df['product_title'].str.lower().str.decode('ISO-8859-1').str.encode('ascii', 'ignore')
def sum_title(df):
    return sum([word in df['titlefix'] for word in df['searchfix']])
df['count_title'] = df.apply(sum_title, axis=1)

# %%
def convert(name):
    s1 = re.sub('(.)([A-Z][a-z]+)', r'\1 \2', name)
    return re.sub('([a-z0-9])([A-Z])', r'\1 \2', s1).lower()

# %%
def num_word_descrp(x):
    """
    count the number of word in common between searchfix column and description in df_description
    """
    return sum([ word in df_description[df_description['product_uid'] == x['product_uid']]['product_description'].values[0].lower() for word in x['searchfix']])

# %%
df['count_common_description'] = df.apply(num_word_descrp, axis=1)

# %%
df_description.iloc[1]['product_description']
# Out:
# 'BEHR Premium Textured DECKOVER is an innovative solid color coating. It will bring your old, weathered wood or concrete back to life. The advanced 100% acrylic resin formula creates a durable coating for your tired and worn out deck, rejuvenating to a whole new look.  For the best results, be sure to properly prepare the surface using other applicable BEHR products displayed above.California residents: see&nbsp;Proposition 65 informationRevives wood and composite decks, railings, porches and boat docks, also great for concrete pool decks, patios and sidewalks100% acrylic solid color coatingResists cracking and peeling and conceals splinters and cracks up to 1/4 in.Provides a durable, mildew resistant finishCovers up to 75 sq. ft. in 2 coats per gallonCreates a textured, slip-resistant finishFor best results, prepare with the appropriate BEHR product for your wood or concrete surfaceActual paint colors may vary from on-screen and printer representationsColors available to be tinted in most storesOnline Price includes Paint Care fee in the following states: CA, CO, CT, ME, MN, OR, RI, VT'

# %%
convert(df_description.iloc[1]['product_description'])
# Out:
# 'behr  premium  textured deckover is an innovative solid color coating.  it will bring your old, weathered wood or concrete back to life.  the advanced 100% acrylic resin formula creates a durable coating for your tired and worn out deck, rejuvenating to a whole new look.   for the best results, be sure to properly prepare the surface using other applicable behr products displayed above. california residents: see&nbsp; proposition 65 information revives wood and composite decks, railings, porches and boat docks, also great for concrete pool decks, patios and sidewalks100% acrylic solid color coating resists cracking and peeling and conceals splinters and cracks up to 1/4 in. provides a durable, mildew resistant finish covers up to 75 sq. ft. in 2 coats per gallon creates a textured, slip-resistant finish for best results, prepare with the appropriate behr product for your wood or concrete surface actual paint colors may vary from on-screen and printer representations colors available to be tinted in most stores online  price includes  paint  care fee in the following states: ca, co, ct, me, mn, or, ri, vt'

# %%
df.head(10)
# Out:
#    id  product_uid                                      product_title  \
# 0   2       100001                  Simpson Strong-Tie 12-Gauge Angle
# 1   3       100001                  Simpson Strong-Tie 12-Gauge Angle
# 2   9       100002  BEHR Premium Textured DeckOver 1-gal. #SC-141 ...
# 3  16       100005  Delta Vero 1-Handle Shower Only Faucet Trim Ki...
# 4  17       100005  Delta Vero 1-Handle Shower Only Faucet Trim Ki...
# 5  18       100006  Whirlpool 1.9 cu. ft. Over the Range Convectio...
# 6  20       100006  Whirlpool 1.9 cu. ft. Over the Range Convectio...
# 7  21       100006  Whirlpool 1.9 cu. ft. Over the Range Convectio...
# 8  23       100007  Lithonia Lighting Quantum 2-Light Black LED Em...
# 9  27       100009  House of Fara 3/4 in. x 3 in. x 8 ft. MDF Flut...
#
#             search_term  relevance                searchfix  \
# 0         angle bracket       3.00          [angl, bracket]
# 1             l bracket       2.50             [l, bracket]
# 2             deck over       3.00             [deck, over]
# 3      rain shower head       2.33     [rain, shower, head]
# 4    shower only faucet       2.67   [shower, onli, faucet]
# 5        convection otr       3.00           [convect, otr]
# 6  microwave over stove       2.67  [microwav, over, stove]
# 7            microwaves       3.00               [microwav]
# 8       emergency light       2.67           [emerg, light]
# 9               mdf 3/4       3.00               [mdf, 3/4]
#
#                                             titlefix  count_title  \
# 0                  simpson strong-tie 12-gauge angle            1
# 1                  simpson strong-tie 12-gauge angle            1
# 2  behr premium textured deckover 1-gal. #sc-141 ...            2
# 3  delta vero 1-handle shower only faucet trim ki...            1
# 4  delta vero 1-handle shower only faucet trim ki...            2
# 5  whirlpool 1.9 cu. ft. over the range convectio...            1
# 6  whirlpool 1.9 cu. ft. over the range convectio...            2
# 7  whirlpool 1.9 cu. ft. over the range convectio...            1
# 8  lithonia lighting quantum 2-light black led em...            2
# 9  house of fara 3/4 in. x 3 in. x 8 ft. mdf flut...            2
#
#    count_common_description
# 0                         1
# 1                         1
# 2                         2
# 3                         1
# 4                         2
# 5                         2
# 6                         2
# 7                         1
# 8                         2
# 9                         2

# %%
brandnames = df_attributes[df_attributes.name == "MFG Brand Name"][['product_uid', 'value']]
brandnames.index = brandnames['product_uid']
brandnames.value = brandnames.value.str.lower()
# df_search = df[['product_uid', 'search_term']]
# df_search['search_term'] = df_search.search_term.str.split()

# %%
df_search2 = df.join(brandnames, on='product_uid', lsuffix='l', rsuffix='r').drop(['product_uidl', 'product_uidr'], axis=1)
df_search2.fillna('NaN', inplace=True)
df_search2['cnt'] = df_search2.apply(lambda row: sum(row.value.find(word.encode('ascii', 'ignore')) > 0 for word in row.searchfix), axis=1)

# %%
df_search2.head()
# Out:
#    id                                      product_title         search_term  \
# 0   2                  Simpson Strong-Tie 12-Gauge Angle       angle bracket
# 1   3                  Simpson Strong-Tie 12-Gauge Angle           l bracket
# 2   9  BEHR Premium Textured DeckOver 1-gal. #SC-141 ...           deck over
# 3  16  Delta Vero 1-Handle Shower Only Faucet Trim Ki...    rain shower head
# 4  17  Delta Vero 1-Handle Shower Only Faucet Trim Ki...  shower only faucet
#
#    relevance               searchfix  \
# 0       3.00         [angl, bracket]
# 1       2.50            [l, bracket]
# 2       3.00            [deck, over]
# 3       2.33    [rain, shower, head]
# 4       2.67  [shower, onli, faucet]
#
#                                             titlefix  count_title  \
# 0                  simpson strong-tie 12-gauge angle            1
# 1                  simpson strong-tie 12-gauge angle            1
# 2  behr premium textured deckover 1-gal. #sc-141 ...            2
# 3  delta vero 1-handle shower only faucet trim ki...            1
# 4  delta vero 1-handle shower only faucet trim ki...            2
#
#    count_common_description                           value  cnt
# 0                         1              simpson strong-tie    0
# 1                         1              simpson strong-tie    0
# 2                         2  behr premium textured deckover    2
# 3                         1                           delta    0
# 4                         2                           delta    0

# %% [markdown]
# # Modeling using Random Forest

# %%
X = df_search2[['count_title','count_common_description','cnt']]
y = df_search2['relevance']

# %%
RF_mod = RandomForestRegressor(50)
cross_val_score(RF_mod, X, y, cv=5, scoring='r2')
# Out:
# array([ 0.05747352,  0.05582343,  0.03605256,  0.04660999, -0.1266012 ])

# %%
z4 = zipfile.ZipFile('data/test.csv.zip')
df4 = pd.read_csv(z4.open('test.csv'))

# %%
for i in df['product_title']:
    z = i.find(". 0")
    if z>=0:
        print i
# Out:
# dewalt tstak 44lb. 0-drawer deep box with flat top
# kraus all-in-on undermount stainless steel 32.3in. 0-hole doubl bowl kitchen sink
# yosemit home decor undermount stainless steel 23in. 0-hole singl bowl kitchen sinkin. satin
# elkay lusterton undermount stainless steel 31in. 0-hole singl bowl kitchen sinkin. satin
# elkay lusterton undermount stainless steel 31-3/4 xbi 16-1/2 xbi 7-1/2in. 0-hole doubl bowl kitchen sink
# elkay signatur plus undermount stainless steel 24in. 0-hole singl bowl kitchen sink
# builder edg paint head metal screwsin. 023 wicker (12-pack)
# builder edg paint head metal screwsin. 078 wineberri (12-pack)
# 3m hand-mask 6ft. xbi 90ft. 0.35 mil pre-fold mask film
# vigo undermount 32in. 0-hole singl bowl kitchen sink with grid and strainerin. stainless steel
# builder edg paint head metal screwsin. 020 cream (12-pack)
# sterl carthag undermount stainless steel 32in. 0-hole doubl bowl kitchen sink
# schon all-in-on undermount stainless steel 30in. 0-hole doubl bowl kitchen sink with faucet
# schon all-in-on undermount stainless steel 30in. 0-hole doubl bowl kitchen sink with faucet
# kraus all-in-on undermount stainless steel 32in. 0-hole doubl bowl kitchen sink
# kraus all-in-on undermount stainless steel 32in. 0-hole doubl bowl kitchen sink
# kraus all-in-on undermount stainless steel 32in. 0-hole doubl bowl kitchen sink
# builder edg paint head metal screwsin. 030 paintabl (12-pack)
# builder edg paint head metal screwsin. 030 paintabl (12-pack)
# blanco stellar undermount stainless steel 33.4in. 0-hole equal doubl bowl kitchen sink
# builder edg 73-5/8in. ellipt sunburstin. 008 clay-discontinu
# schon all-in-on undermount stainless steel 30in. 0-hole doubl bowl kitchen sink with faucet
# schon all-in-on undermount stainless steel 30-1/4in. 0-hole doubl bowl kitchen sink with faucet
# schon all-in-on undermount stainless steel 30-1/2in. 0-hole singl bowl kitchen sink
# elkay lusterton undermount stainless steel 31in. 0-hole doubl bowl kitchen sink
# premier copper product under counter/surface-mount round hammer copper 16in. 0-hole bar sinkin. oil rub bronz with fleur de lis
# schon all-in-on undermount stainless steel 30in. 0-hole singl bowl kitchen sink
# schon all-in-on undermount stainless steel 30in. 0-hole singl bowl kitchen sink
# schon all-in-on undermount stainless steel 30in. 0-hole singl bowl kitchen sink
# vigo all-in-on undermount stainless steel 23 xbi 9.875 xbi 10in. 0-hole singl bowl kitchen sink and faucet set
# schon all-in-on undermount stainless steel 30in. 0-hole doubl bowl kitchen sink with faucet
# schon all-in-on undermount stainless steel 30in. 0-hole doubl bowl kitchen sink with faucet
# vigo all-in-on farmhous apron front stainless steel 36in. 0-hole singl bowl kitchen sink and faucet set
# builder edg paint head metal screwsin. 016 light grey (12-pack)
# sinkolog o&#39;keef undermount handmad pure solid copper 30in. 0-hole singl bowl kitchen sinkin. antiqu copper
# hdx 9ft. xbi 12ft. 0.7 mil drop cloth (3-pack)
# builder edg paint head metal screwsin. 002 black (12-pack)
# builder edg paint head metal screwsin. 002 black (12-pack)
# kingston brass undermount stainless steel 30in. 0-hole singl bowl kitchen sinkin. satin
# blanco stellar undermount stainless steel 28in. 0-hole super singl bowl kitchen sink
# blanco stellar undermount stainless steel 28in. 0-hole super singl bowl kitchen sink
# premier copper product under counter/surface-mount round hammer copper 14in. 0-hole bar sinkin. oil rub bronz with 2in. drain size
# premier copper product under counter/surface-mount round hammer copper 14in. 0-hole bar sinkin. oil rub bronz with 2in. drain size
# builder edg 9in. xbi 65 5/8in. j-channel back-plat for window headerin. 001 white
# blanco spex plus undermount stainless steel 23in. 0-hole singl bowl kitchen sink
# hdx 9ft. xbi 400ft. 0.31 mil high densiti plastic painter
# hdx 9ft. xbi 12ft. 0.7 mil drop cloth
# alaska 32oz. 0-10-10 morbloom fertil
# blanco preci undermount granit composit 32in. 0-hole super singl bowl kitchen sinkin. white
# builder edg 65-5/8in. ellipt sunburstin. 008 clay-discontinu
# elkay mystic undermount stainless steel 18in. 0-hole singl bowl bar sink
# elkay mystic undermount stainless steel 18in. 0-hole singl bowl bar sink
# builder edg 9in. xbi 37 5/8in. j-channel back-plat for window headerin. 001 white
# kraus all-in-on undermount stainless steel 32in. 0-hole doubl bowl kitchen sink
# rever elkay undermount stainless steel 31in. 0-hole bowl kitchen sink
# vigo undermount farmhous apron front 33in. 0-hole singl bowl kitchen sink with grid and strainerin. stainless steel
# blanco diamond undermount granit composit 32in. 0-hole 1-3/4 bowl kitchen sinkin. cafe brown
# hdx 9ft. xbi 12ft. 0.7 mil drop cloth (6-pack)
# hdx 9ft. xbi 12ft. 0.7 mil drop cloth (6-pack)
# kraus all-in-on undermount stainless steel 23 xbi 18 xbi 11in. 0-hole singl bowl kitchen sink with oil rub bronz accessori
# echo cross-fir 282ft. 0.095in. premium nylon trimmer line
# echo cross-fir 282ft. 0.095in. premium nylon trimmer line
# builder edg 6in. xbi 37 5/8in. j-channel back-plat for window headerin. 001 white
# vigo all-in-on undermount stainless steel 30 xbi 19 xbi 10in. 0-hole singl bowl kitchen sink and faucet set
# vigo all-in-on undermount stainless steel 30 xbi 19 xbi 10in. 0-hole singl bowl kitchen sink and faucet setin. chrome
# 1/2in. 0.700 o. d. compress coupl
# vigo all-in-on farmhous apron front stainless steel 36in. 0-hole singl bowl kitchen sink
# vigo all-in-on farmhous apron front stainless steel 30in. 0-hole singl bowl kitchen sink and faucet setin. chrome
# moen 2000 seri undermount stainless steel 23in. 0-hole singl bowl kitchen sink
# moen 2000 seri undermount stainless steel 24in. 0-hole doubl bowl kitchen sink
# builder edg 6in. xbi 37-5/8in. flat panel window header with keystonein. 030 paintabl
# builder edg 6in. xbi 37-5/8in. flat panel window header with keystonein. 030 paintabl
# builder edg 6in. xbi 33-5/8in. flat panel window header with keystonein. 002 black
# builder edg 2-5/8in. xbi 6in. xbi 37-5/8in. composit flat panel window header with keystonein. 018 tuxedo gray
# schon all-in-on undermount stainless steel 30-1/4in. 0-hole doubl bowl kitchen sink with faucet
# vigo all-in-on farmhous apron front stainless steel 36in. 0-hole singl bowl kitchen sinkin. matt black
# builder edg paint head metal screwsin. 018 tuxedo gray (12-pack)
# builder edg paint head metal screwsin. 018 tuxedo gray (12-pack)
# vigo all-in-on undermount stainless steel 30 xbi 19 xbi 10in. 0-hole singl bowl kitchen sink and faucet setin. chrome
# builder edg paint head metal screwsin. 001 white (12-pack)
# vigo all-in-on undermount stainless steel 32 xbi 9.875 xbi 10in. 0-hole singl bowl kitchen sink and faucet set
# bell foret undermount stainless steel 30in. 0-hole singl bowl kitchen sink
# bell foret undermount stainless steel 30in. 0-hole singl bowl kitchen sink
# swanston undermount composit 33 xbi 21-1/4 xbi 8-1/4in. 0-hole doubl bowl kitchen sinkin. white
# elkay lusterton undermount stainless steel 15in. 0-hole singl bowl kitchen sink
# builder edg paint head metal screwsin. 036 classic blue (12-pack)
# builder edg 6in. xbi 43 5/8in. classic dentil window header with keystonein. 008 clay
# moen 2000 seri undermount stainless steel 29.25in. 0-hole doubl bowl kitchen sink
# 1/2in. 0.710 od compress coupl
# schock edo top mount composit 33in. 0-hole 70/30 doubl bowl kitchen sinkin. onyx
# schon undermount stainless steel 19-1/8in. 0-hole singl bowl vaniti sink
# vigo all-in-on farmhous apron front stainless steel 33in. 0-hole doubl bowl kitchen sinkin. antiqu rub bronz
# 1/2in. 0.700 o. d. compress tee
# whitehaus collect undermount brush stainless steel 29.5 xbi 17.5 xbi 8.625in. 0-hole singl bowl kitchen sink
# premier copper product all-in-on undermount hammer copper 33in. 0-hole 60/40 doubl bowl kitchen sinkin. oil rub bronz
# builder edg 3-3/4in. xbi 9in. xbi 33-5/8in. composit flat panel window header with keystonein. 018 tuxedo gray
# builder edg 6in. xbi 73 5/8in. j-channel back-plat for window headerin. 030 paintabl
# kohler 8 deg. undermount stainless steel 33in. 0-hole doubl bowl kitchen sink
# vigo all-in-on farmhous apron front stainless steel 36in. 0-hole doubl bowl kitchen sink and chrome faucet set
# schon all-in-on undermount stainless steel 30in. 0-hole doubl bowl kitchen sink with faucet
# whitehaus collect noah&#39; collect undermount stainless steel 32in. 0-hole singl bowl kitchen sinkin. brush stainless steel
# kohler iron/ton dual mount cast-iron 33in. 0-hole smart divid doubl bowl kitchen sinkin. black n&#39; tan
# vigo all-in-on farmhous apron front stainless steel 33in. 0-hole doubl bowl kitchen sink and faucet setin. chrome
# blanco diamond undermount granit 24in. 0-hole singl bowl kitchen sinkin. anthracit
# blanco stellar undermount stainless steel 31.75in. 0-hole 1.6 revers doubl bowl kitchen sink
# schon all-in-on undermount stainless steel 30in. 0-hole singl bowl kitchen sink with faucet
# schon all-in-on undermount stainless steel 30in. 0-hole singl bowl kitchen sink with faucet
# builder edg 9in. xbi 128in. j-channel back-plat for window headerin. 030 paintabl
# whitehaus collect undermount stainless steel 23-1/4 xbi 20-7/8 xbi 9in. 0-hole singl bowl kitchen sinkin. brush stainless steel
# toro 570z pro seri 15ft. 4in. 0-360-deg. van pop-up sprinkler
# builder edg 9in. xbi 65-5/8in. flat panel window header with keystonein. 008 clay
# builder edg 6in. xbi 65 5/8in. j-channel back-plat for window headerin. 001 white
# whitehaus collect noah&#39; collect undermount stainless steel 29-1/2in. 0-hole doubl bowl kitchen sink
# vigo all-in-on farmhous apron front stainless steel 36in. 0-hole doubl bowl kitchen sink and chrome faucet set
# whitehaus collect basichaus apron front fireclay 32in. 0-hole doubl bowl kitchen sinkin. white
# vigo all-in-on farmhous apron front stainless steel 36in. 0-hole doubl bowl kitchen sinkin. chrome
# vigo undermount 30in. 0-hole singl bowl kitchen sink with grid and strainerin. stainless steel
# vigo undermount 30in. 0-hole singl bowl kitchen sink with grid and strainerin. stainless steel
# blanco diamond undermount composit 32in. 0-hole doubl bowl kitchen sinkin. biscuit
# blanco diamond undermount composit 32in. 0-hole doubl bowl kitchen sinkin. biscuit
# schon all-in-on undermount stainless steel 30in. 0-hole doubl bowl kitchen sink with faucet
# schon all-in-on undermount stainless steel 30in. 0-hole doubl bowl kitchen sink with faucet
# kohler iron/ton dual mount cast-iron 33in. 0-hole smart divid doubl bowl kitchen sinkin. sea salt
# vigo all-in-on farmhous apron front stainless steel 33in. 0-hole doubl bowl kitchen sink setin. chrome
# builder edg 9in. xbi 43-5/8in. flat panel window header with keystonein. 078 wineberri
# schock edo cristadur topmount granit composit 33in. 0-hole 50/50 doubl bowl kitchen sinkin. earth
# builder edg paint head metal screwsin. 028 forest green (12-pack)
# builder edg 6in. xbi 37 5/8in. classic dentil window header with keystonein. 001 white
# builder edg shutter lok fastenersin. 027 burgundi red (12-pack)
# swan dual mount granit 33 xbi 22 xbi 9in. 0-hole even doubl bowl kitchen sinkin. espresso
# blanco stellar undermount stainless steel 31.75in. 0-hole 1.6 doubl bowl kitchen sink
# vigo all-in-on undermount stainless steel 32in. 0-hole singl bowl kitchen sink and faucet setin. chrome
# vigo all-in-on farmhous apron front stainless steel 36in. 0-hole doubl bowl kitchen sink and chrome faucet set
# 3/4in. femal hose thread xbi 1/2in. 0.700 o. d. compress swivel adapt
# builder edg 3-3/4in. xbi 9in. xbi 73-5/8in. composit classic dentil window header with keystonein. 009 feder brown
# blanco stellar undermount stainless steel 25in. 0-hole medium singl bowl kitchen sink
# schock edo undermount composit 33in. 0-hole 50/50 doubl bowl kitchen sinkin. basalt
# vigo all-in-on farmhous apron front stainless steel 33in. 0-hole singl bowl kitchen sink and faucet setin. chrome
# schon all-in-on undermount stainless steel 28in. 0-hole singl bowl kitchen sink with faucet
# schock edo undermount composit 33in. 0-hole 70/30 doubl bowl kitchen sinkin. basalt
# blanco diamond undermount granit 24in. 0-hole singl bowl kitchen sinkin. biscotti
# builder edg paint head metal screwsin. 009 feder brown (12-pack)
# hdx 12ft. xbi 400ft. 0.31 mil high densiti painter plastic sheet
# whitehaus collect noah&#39; collect wall mount stainless steel 44 xbi 13.25 xbi 15in. 0-hole singl bowl kitchen sink
# mont blanc westminst dual mount composit granit 16in. 0-hole singl bowl bar sinkin. white
# schock edo undermount composit 33in. 0-hole 70/30 doubl bowl kitchen sinkin. onyx
# kohler 8 deg. undermount stainless steel 33in. 0-hole singl bowl kitchen sink
# builder edg 2-5/8in. xbi 6in. xbi 65-5/8in. composit flat panel window header with keystonein. 027 burgundi red
# builder edg 2-5/8in. xbi 6in. xbi 73-5/8in. composit classic dentil window header with keystonein. 009 feder brown
# schock edo undermount composit 33in. 0-hole 70/30 doubl bowl kitchen sinkin. mocha
# builder edg shutter lok fastenersin. 078 wineberri (12-pack)
# schon all-in-on undermount stainless steel 29-1/2in. 0-hole doubl bowl kitchen sink with faucet
# builder edg 2-5/8in. xbi 6in. xbi 37-5/8in. composit classic dentil window header with keystonein. 027 burgundi red
# builder edg 6in. xbi 65 5/8in. classic dentil window header with keystonein. 023 wicker
# vigo undermount stainless steel 29in. 0-hole doubl bowl kitchen sink with grid and strainer
# swanston dual mount composit 18.5 xbi 18.5 xbi 8.5in. 0-hole round bowl kitchen sinkin. bone
# builder edg 2-5/8in. xbi 6in. xbi 65-5/8in. composit classic dentil window header with keystonein. 009 feder brown
# blanco diamond undermount granit 32in. 0-hole doubl bowl kitchen sinkin. white
# vigo all-in-on undermount stainless steel 23 xbi 20 xbi 10.25in. 0-hole singl bowl kitchen sink with faucet set
# schon all-in-on undermount stainless steel 30in. 0-hole doubl bowl kitchen sink with faucet

# %%
#function to clean strings
def str_stem(s):
    if isinstance(s, str):
        s = s.decode('ISO-8859-1').encode('ascii', 'ignore').lower()
        
        # 
        s = s.replace(".",". ")
        s = s.replace(". 0",".0")
        s = s.replace(". 1",".1")
        s = s.replace(". 2",".2")
        s = s.replace(". 3",".3")
        s = s.replace(". 4",".4")
        s = s.replace(". 5",".5")
        s = s.replace(". 6",".6")
        s = s.replace(". 7",".7")
        s = s.replace(". 8",".8")
        s = s.replace(". 9",".9")
        s = s.replace("  "," ")

        s = s.replace("'","in.")
        s = s.replace("inches","in.")
        s = s.replace("inch","in.")
        s = s.replace(" in ","in. ")
        s = s.replace(" in.","in.")

        s = s.replace("''","ft.")
        s = s.replace(" feet ","ft. ")
        s = s.replace("feet","ft.")
        s = s.replace("foot","ft.")
        s = s.replace(" ft ","ft. ")
        s = s.replace(" ft.","ft.")

        s = s.replace(" pounds ","lb. ")
        s = s.replace(" pound ","lb. ")
        s = s.replace("pound","lb.")
        s = s.replace(" lb ","lb. ")
        s = s.replace(" lb.","lb.")
        s = s.replace(" lbs ","lb. ")
        s = s.replace("lbs.","lb.")

        s = s.replace(" x "," xby ")
        s = s.replace("*"," xby ")
        s = s.replace(" by "," xby")
        s = s.replace("x0"," xby 0")
        s = s.replace("x1"," xby 1")
        s = s.replace("x2"," xby 2")
        s = s.replace("x3"," xby 3")
        s = s.replace("x4"," xby 4")
        s = s.replace("x5"," xby 5")
        s = s.replace("x6"," xby 6")
        s = s.replace("x7"," xby 7")
        s = s.replace("x8"," xby 8")
        s = s.replace("x9"," xby 9")
        s = s.replace("0x","0 xby ")
        s = s.replace("1x","1 xby ")
        s = s.replace("2x","2 xby ")
        s = s.replace("3x","3 xby ")
        s = s.replace("4x","4 xby ")
        s = s.replace("5x","5 xby ")
        s = s.replace("6x","6 xby ")
        s = s.replace("7x","7 xby ")
        s = s.replace("8x","8 xby ")
        s = s.replace("9x","9 xby ")

        s = s.replace(" sq ft","sq.ft. ")
        s = s.replace("sq ft","sq.ft. ")
        s = s.replace("sqft","sq.ft. ")
        s = s.replace(" sqft ","sq.ft. ")
        s = s.replace("sq. ft","sq.ft. ")
        s = s.replace("sq ft.","sq.ft. ")
        s = s.replace("sq feet","sq.ft. ")
        s = s.replace("square feet","sq.ft. ")

        s = s.replace(" gallons ","gal. ")
        s = s.replace(" gallon ","gal. ")
        s = s.replace("gallons","gal.")
        s = s.replace("gallon","gal.")
        s = s.replace(" gal ","gal. ")
        s = s.replace(" gal","gal.")

        s = s.replace("ounces","oz.")
        s = s.replace("ounce","oz.")
        s = s.replace(" oz.","oz. ")
        s = s.replace(" oz ","oz. ")

        s = s.replace("centimeters","cm.")
        s = s.replace(" cm.","cm.")
        s = s.replace(" cm ","cm. ")

        s = s.replace("milimeters","mm.")
        s = s.replace(" mm.","mm.")
        s = s.replace(" mm ","mm. ")

        s = s.replace("°","deg. ")
        s = s.replace("degrees","deg. ")
        s = s.replace("degree","deg. ")

        s = s.replace("volts","volt. ")
        s = s.replace("volt","volt. ")

        s = s.replace("watts","watt. ")
        s = s.replace("watt","watt. ")

        s = s.replace("ampere","amp. ")
        s = s.replace("amps","amp. ")
        s = s.replace(" amp ","amp. ")

        s = s.replace("whirpool","whirlpool")
        s = s.replace("whirlpoolga", "whirlpool")
        s = s.replace("whirlpoolstainless","whirlpool stainless")

        s = s.replace("  "," ")
        s = s.replace("..",".")
        #s = (" ").join([stemmer.stem(z) for z in s.lower().split(" ")])
        s = (" ").join([stemmer.stem(z) for z in s.split(" ")])
        return s.lower()
    else:
        return "null"

# %%
def data_cleaning(df_org):
    
    df = df_org.copy()
    
    # stem and lematize search term
    df['searchfix'] = df['search_term'].str.lower().str.decode('ISO-8859-1').str.encode('ascii', 'ignore').str.split()\
    .apply(lambda x: [stemmer.stem(item) for item in x]) \
    .apply(lambda x: [wordnet.lemmatize(item) for item in x])
    # count common word between search term and title

    df['titlefix'] = df['product_title'].str.lower().str.decode('ISO-8859-1').str.encode('ascii', 'ignore')
    def sum_title(df):
        return sum([word in df['titlefix'] for word in df['searchfix']])
    df['count_title'] = df.apply(sum_title, axis=1)

    
    # count common word between search term and df_description
    def num_word_descrp(x):
        """
        count the number of word in common between searchfix column and description in df_description
        """
        return sum([ word in df_description[df_description['product_uid'] == x['product_uid']]['product_description'].values[0].lower() for word in x['searchfix']])

    df['count_common_description'] = df.apply(num_word_descrp, axis=1)


    # count common word between search term and brand name fro df_attributes
    brandnames = df_attributes[df_attributes.name == "MFG Brand Name"][['product_uid', 'value']]
    brandnames.index = brandnames['product_uid']
    brandnames.value = brandnames.value.str.lower()

    df_search2 = df.join(brandnames, on='product_uid', lsuffix='l', rsuffix='r')#.drop(['product_uidl', 'product_uidr'], axis=1)
    df_search2.fillna('NaN', inplace=True)
    df_search2['cnt'] = df_search2.apply(lambda row: sum(row.value.find(word) > 0 for word in row.search_term), axis=1)


    return df_search2

# %%
df_train = data_cleaning(df)

# %%
df_test = data_cleaning(df4)

# %%
def modeling(estimator, df, df_test, submission=False):
    X = df['count_title']
    y = df['relevance']
    X_test = df_test['count_title']
    estimator.fit(X, y)
    
    result = estimator.predict(X_test)
    
    output_df= pd.DataFrame(df_test['id'],columns=['id',"relevance"])
    output_df['relevance'] = result
    output_df['relevance'] = output_df['relevance'].apply(lambda x: 3 if x>3 else x)
    output_df['relevance'] = output_df['relevance'].apply(lambda x: 1 if x<1 else x) 
    
    
    if submission:
        output_df.to_csv('submission.csv',index=False)
        
    return estimator

# %%
df_train['attribute_names']  = df_train.apply(lambda df: ' '.join(df_attributes[df_attributes['product_uid']==df['id']]['name']))

# %%
df_attributes[df_attributes['product_uid']==df_train.iloc[0]['product_uidl']]['name']

# %%
t = TfidfVectorizer(stop_words='english')

# %%
df['product_title'] = df['product_title'].apply(str_stem)

# %%
df_tfidf = df['product_title'].unique() 
df_tfidf
# Out:
# array([u'simpson strong-ti 12-gaug angl',
#        u'behr premium textur deckov 1-gal. #sc-141 tugboat wood and concret coat',
#        u'delta vero 1-handl shower onli faucet trim kitin. chrome (valv not included)',
#        ...,
#        u'schlage camelot in-act age bronz handleset with left-hand accent lever',
#        u'plastec 11in. xbi 24in. rose garden wall decor steel',
#        u'lichtenberg pool blue no. 918 millenni ryan heather textur sheer curtain panel, 40in. w xbi 63in. l'], dtype=object)

# %%
df_tfidf = pd.Series(df['product_title'].unique()).str.lower().str.decode('ISO-8859-1').str.encode('ascii', 'ignore').str.split()\
    .apply(lambda x: [stemmer.stem(item) for item in x]) \
    .apply(lambda x: [wordnet.lemmatize(item) for item in x])

# %%
df_tfidf = [" ".join(title) for title in df_tfidf]

# %%
title_vect = t.fit_transform(df_tfidf)

# %%
# Out:
# <53468x17863 sparse matrix of type '<type 'numpy.float64'>'
# 	with 521911 stored elements in Compressed Sparse Row format>

# %%
t.get_feature_names()
# Out:
# [u'00',
#  u'000',
#  u'0000',
#  u'00003g',
#  u'000d_',
#  u'000ft',
#  u'000gal',
#  u'000in',
#  u'000lb',
#  u'001',
#  u'002',
#  u'003',
#  u'00304',
#  u'004',
#  u'005',
#  u'006',
#  u'006in',
#  u'0070a',
#  u'007e',
#  u'008',
#  u'009',
#  u'00in',
#  u'01',
#  u'010',
#  u'010c',
#  u'011',
#  u'012',
#  u'012in',
#  u'012j',
#  u'013',
#  u'014a',
#  u'014c',
#  u'015b',
#  u'016',
#  u'016in',
#  u'018',
#  u'018b',
#  u'01e',
#  u'01f',
#  u'01s',
#  u'02',
#  u'020',
#  u'021',
#  u'022',
#  u'022in',
#  u'023',
#  u'024in',
#  u'025in',
#  u'027',
#  u'028',
#  u'02ft',
#  u'02in',
#  u'03',
#  u'030',
#  u'0301172',
#  u'0306140',
#  u'032',
#  u'0323016',
#  u'032in',
#  u'035in',
#  u'036',
#  u'0393in',
#  u'04',
#  u'04014',
#  u'04050',
#  u'040in',
#  u'041a',
#  u'043in',
#  u'044',
#  u'045',
#  u'045in',
#  u'047',
#  u'047107',
#  u'047b',
#  u'049',
#  u'0498096',
#  u'04in',
#  u'05',
#  u'050',
#  u'050in',
#  u'051a',
#  u'051c',
#  u'052',
#  u'05307',
#  u'05in',
#  u'05mm',
#  u'06',
#  u'0625in',
#  u'062in',
#  u'063in',
#  u'065',
#  u'065in',
#  u'066a',
#  u'069',
#  u'06in',
#  u'06oz',
#  u'07',
#  u'075in',
#  u'076',
#  u'077',
#  u'078',
#  u'08',
#  u'080',
#  u'080b',
#  u'080in',
#  u'082',
#  u'082in',
#  u'083d',
#  u'085',
#  u'086',
#  u'089',
#  u'08in',
#  u'09',
#  u'090',
#  u'091a',
#  u'091b',
#  u'092',
#  u'092in',
#  u'093in',
#  u'095',
#  u'095in',
#  u'097',
#  u'099c',
#  u'099in',
#  u'09in',
#  u'0ah',
#  u'0amp',
#  u'0ft',
#  u'0gal',
#  u'0in',
#  u'10',
#  u'100',
#  u'1000',
#  u'10000',
#  u'1000_f',
#  u'1000amp',
#  u'1000ft',
#  u'1000lb',
#  u'1000mah',
#  u'1000tvl',
#  u'1001',
#  u'1007',
#  u'1008',
#  u'1008in',
#  u'100amp',
#  u'100b',
#  u'100c',
#  u'100e',
#  u'100fd',
#  u'100ft',
#  u'100gal',
#  u'100in',
#  u'100k',
#  u'100ka',
#  u'100lb',
#  u'100oz',
#  u'100s',
#  u'100th',
#  u'100w',
#  u'101',
#  u'10100',
#  u'101c',
#  u'101ft',
#  u'101gal',
#  u'101in',
#  u'101l',
#  u'102',
#  u'1021e',
#  u'1028',
#  u'102in',
#  u'102oz',
#  u'103',
#  u'1038',
#  u'103in',
#  u'104',
#  u'1040',
#  u'1042',
#  u'1045',
#  u'104a',
#  u'104c',
#  u'104d',
#  u'104f',
#  u'104in',
#  u'105',
#  u'1050',
#  u'1050gal',
#  u'1054em',
#  u'105gal',
#  u'105in',
#  u'105mm',
#  u'106',
#  u'1060',
#  u'1064',
#  u'10641',
#  u'1067em',
#  u'106in',
#  u'107',
#  u'1073',
#  u'108',
#  u'1080',
#  u'1080p',
#  u'108in',
#  u'109',
#  u'1090',
#  u'10amp',
#  u'10b',
#  u'10d',
#  u'10en',
#  u'10ft',
#  u'10g',
#  u'10gal',
#  u'10h',
#  u'10hp',
#  u'10i',
#  u'10in',
#  u'10lb',
#  u'10mm',
#  u'10oz',
#  u'10w',
#  u'11',
#  u'110',
#  u'1100',
#  u'11000',
#  u'11000ez',
#  u'1100lb',
#  u'1101',
#  u'1102',
#  u'1107',
#  u'110_',
#  u'110amp',
#  u'110d',
#  u'110ft',
#  u'110gal',
#  u'110in',
#  u'110lb',
#  u'110v',
#  u'111',
#  u'111fd',
#  u'111in',
#  u'111md',
#  u'111sd',
#  u'112',
#  u'11213',
#  u'1123dset',
#  u'1128',
#  u'112in',
#  u'113',
#  u'1132',
#  u'113gal',
#  u'113in',
#  u'114',
#  u'114in',
#  u'115',
#  u'1150',
#  u'1159',
#  u'115in',
#  u'115v',
#  u'116',
#  u'116gal',
#  u'116in',
#  u'117',
#  u'117in',
#  u'118',
#  u'118in',
#  u'118mm',
#  u'119',
#  u'11amp',
#  u'11b',
#  u'11ft',
#  u'11gal',
#  u'11in',
#  u'11k',
#  u'11lb',
#  u'11oz',
#  u'11w',
#  u'11z',
#  u'12',
#  u'120',
#  u'1200',
#  u'12000',
#  u'1200b',
#  u'1200ft',
#  u'1200gal',
#  u'1200lb',
#  u'1200mah',
#  u'1201',
#  u'120b',
#  u'120f',
#  u'120ft',
#  u'120g',
#  u'120gal',
#  u'120hz',
#  u'120in',
#  u'120lb',
#  u'120mm',
#  u'120oz',
#  u'120v',
#  u'120w',
#  u'121',
#  u'1219',
#  u'121in',
#  u'122',
#  u'1222',
#  u'1225',
#  u'122in',
#  u'123',
#  u'12361',
#  u'12362',
#  u'123cc',
#  u'123gal',
#  u'124',
#  u'125',
#  u'1250',
#  u'1250w',
#  u'125amp',
#  u'125cc',
#  u'125ft',
#  u'125in',
#  u'125lb',
#  u'126',
#  u'1260',
#  u'126in',
#  u'127',
#  u'1270',
#  u'127d',
#  u'128',
#  u'1280',
#  u'1280tvl',
#  u'128in',
#  u'128mm',
#  u'128oz',
#  u'129',
#  u'1295d',
#  u'12amp',
#  u'12b',
#  u'12d',
#  u'12ft',
#  u'12g0cd3744',
#  u'12gal',
#  u'12in',
#  u'12k',
#  u'12kw',
#  u'12lb',
#  u'12mm',
#  u'12oz',
#  u'12sq',
#  u'12v',
#  u'13',
#  u'130',
#  u'1300',
#  u'130e',
#  u'130ft',
#  u'130gal',
#  u'130in',
#  u'130lb',
#  u'131',
#  u'131b',
#  u'131in',
#  u'132',
#  u'1320ft',
#  u'1320lb',
#  u'1326',
#  u'132in',
#  u'133h',
#  u'134',
#  u'134a',
#  u'135',
#  u'1350',
#  u'135ft',
#  u'135in',
#  u'135k',
#  u'136',
#  u'136gal',
#  u'137',
#  u'138',
#  u'138in',
#  u'138oz',
#  u'139',
#  u'139cc',
#  u'13a',
#  u'13amp',
#  u'13ft',
#  u'13gal',
#  u'13in',
#  u'13kw',
#  u'13lb',
#  u'13mm',
#  u'13oz',
#  u'14',
#  u'140',
#  u'1400',
#  u'14000',
#  u'1400mah',
#  u'1406',
#  u'1407',
#  u'140b',
#  u'140cc',
#  u'140ft',
#  u'140in',
#  u'140lb',
#  u'140mx',
#  u'140st',
#  u'141',
#  u'1411',
#  u'1414',
#  u'141ft',
#  u'142',
#  u'1420',
#  u'143',
#  u'1430',
#  u'1434',
#  u'143oz',
#  u'144',
#  u'1446',
#  u'144ft',
#  u'144in',
#  u'145',
#  u'1450',
#  u'145in',
#  u'146',
#  u'147',
#  u'1471',
#  u'148',
#  u'148in',
#  u'149cc',
#  u'14a',
#  u'14amp',
#  u'14ft',
#  u'14gal',
#  u'14in',
#  u'14lb',
#  u'14mm',
#  u'14oz',
#  u'14tpi',
#  u'15',
#  u'150',
#  u'1500',
#  u'15000',
#  u'1500ft',
#  u'1500gal',
#  u'1500hrs',
#  u'1500lb',
#  u'1500lbs',
#  u'1500mah',
#  u'1500w',
#  u'1505',
#  u'15060',
#  u'150amp',
#  u'150c',
#  u'150cc',
#  u'150d',
#  u'150ft',
#  u'150gal',
#  u'150in',
#  u'150k',
#  u'150lb',
#  u'150mm',
#  u'150oz',
#  u'150w',
#  u'152',
#  u'1520',
#  u'152120',
#  u'152oz',
#  u'153',
#  u'1530',
#  u'153001',
#  u'153in',
#  u'154',
#  u'155',
#  u'1550',
#  u'155263',
#  u'155in',
#  u'155lb',
#  u'156',
#  u'156in',
#  u'157',
#  u'157in',
#  u'158',
#  u'158117',
#  u'158643',
#  u'159',
#  u'159cc',
#  u'159in',
#  u'15a',
#  u'15amp',
#  u'15ft',
#  u'15gal',
#  u'15in',
#  u'15k',
#  u'15kw',
#  u'15lb',
#  u'15mm',
#  u'15oz',
#  u'15p',
#  u'15r',
#  u'15w',
#  u'16',
#  u'160',
#  u'1600',
#  u'160_',
#  u'160d',
#  u'160in',
#  u'160lb',
#  u'160mm',
#  u'161',
#  u'1617',
#  u'162',
#  u'1625',
#  u'162in',
#  u'163',
#  u'1631whw',
#  u'163cc',
#  u'163e7',
#  u'164',
#  u'1644',
#  u'164ft',
#  u'165',
#  u'1650',
#  u'16500mah',
#  u'1652',
#  u'165ft',
#  u'165in',
#  u'166',
#  u'166d',
#  u'166ft',
#  u'167',
#  u'1675',
#  u'167c',
#  u'167ft',
#  u'168',
#  u'1680',
#  u'168b',
#  u'168in',
#  u'169',
#  u'169b',
#  u'169oz',
#  u'16b',
#  u'16d',
#  u'16ft',
#  u'16gal',
#  u'16gb',
#  u'16h',
#  u'16in',
#  u'16lb',
#  u'16mm',
#  u'16oz',
#  u'17',
#  u'170',
#  u'1700',
#  u'1701',
#  u'170a',
#  u'170c',
#  u'170f',
#  u'170ft',
#  u'170in',
#  u'171',
#  u'172oz',
#  u'173',
#  u'173in',
#  u'174',
#  u'174a',
#  u'175',
#  u'1750',
#  u'175000',
#  u'175a',
#  u'175c',
#  u'175ft',
#  u'175lb',
#  u'176',
#  u'178',
#  u'179',
#  u'179c',
#  u'179e',
#  u'179f',
#  u'17ft',
#  u'17gal',
#  u'17in',
#  u'17k',
#  u'17lb',
#  u'17mm',
#  u'17oz',
#  u'17t',
#  u'18',
#  u'180',
#  u'1800',
#  u'18000',
#  u'1804',
#  u'180_',
#  u'180_floodlight',
#  u'180b',
#  u'180e',
#  u'180f',
#  u'180ft',
#  u'180in',
#  u'180k',
#  u'181',
#  u'1812',
#  u'1822',
#  u'1825',
#  u'182ft',
#  u'183',
#  u'1840',
#  u'185',
#  u'1850',
#  u'1857',
#  u'1866',
#  u'187',
#  u'1873',
#  u'1875',
#  u'1875in',
#  u'1887',
#  u'1888',
#  u'188ft',
#  u'188in',
#  u'189',
#  u'1890',
#  u'1897',
#  u'189ft',
#  u'189in',
#  u'18amp',
#  u'18ft',
#  u'18gal',
#  u'18in',
#  u'18kw',
#  u'18lb',
#  u'18mm',
#  u'18oz',
#  u'18sq',
#  u'18tpi',
#  u'18w',
#  u'19',
#  u'190',
#  u'1900',
#  u'1902',
#  u'190f',
#  u'191',
#  u'1911',
#  u'1914',
#  u'192',
#  u'1920',
#  u'1925',
#  u'1926',
#  u'192ft',
#  u'192in',
#  u'192oz',
#  u'1930',
#  u'1940lb',
#  u'195',
#  u'1952',
#  u'195gal',
#  u'196in',
#  u'197',
#  u'1973',
#  u'198',
#  u'1980',
#  u'199',
#  u'1996',
#  u'1997',
#  u'1998',
#  u'1999',
#  u'19ft',
#  u'19in',
#  u'19mm',
#  u'19oz',
#  u'19w',
#  u'1a',
#  u'1a10bc',
#  u'1a5',
#  u'1a6',
#  u'1amp',
#  u'1b1',
#  u'1b24',
#  u'1b42',
#  u'1c',
#  u'1d',
#  u'1ea',
#  u'1ft',
#  u'1gal',
#  u'1h',
#  u'1in',
#  u'1kg',
#  u'1l',
#  u'1lb',
#  u'1m',
#  u'1mgal',
#  u'1mm',
#  u'1mp',
#  u'1oz',
#  u'1pack',
#  u'1piec',
#  u'1pk',
#  u'1r',
#  u'1st',
#  u'1tb',
#  u'1watt',
#  u'1zehtmr',
#  u'20',
#  u'200',
#  u'2000',
#  u'20000',
#  u'2000ft',
#  u'2000iq',
#  u'2000lb',
#  u'2000ma',
#  u'2000mah',
#  u'2001',
#  u'2002',
#  u'2003',
#  u'2004',
#  u'2005',
#  u'2006',
#  u'2007',
#  u'2007in',
#  u'2008',
#  u'2009',
#  u'200a',
#  u'200amp',
#  u'200cm',
#  u'200ft',
#  u'200gal',
#  u'200k',
#  u'200lb',
#  u'200mm',
#  u'200oz',
#  u'200pd',
#  u'200wm',
#  u'201',
#  u'2010',
#  u'2010in',
#  u'2011',
#  u'2012',
#  u'2013',
#  u'2014',
#  u'2015',
#  u'2015in',
#  u'2016',
#  u'202',
#  u'2024',
#  u'2025',
#  u'203',
#  u'2030',
#  u'2032',
#  u'204',
#  u'204in',
#  u'205',
#  u'2050',
#  u'2054',
#  u'2057',
#  u'2057a',
#  u'205cc',
#  u'205in',
#  u'206',
#  u'2060',
#  u'2065lb',
#  u'207',
#  u'2071',
#  u'207b',
#  u'208',
#  u'208cc',
#  u'208r',
#  u'208v',
#  u'209',
#  u'20amp',
#  u'20es',
#  u'20evs',
#  u'20ft',
#  u'20gal',
#  u'20in',
#  u'20kv',
#  u'20l',
#  u'20lb',
#  u'20mm',
#  u'20oz',
#  u'20w',
#  u'21',
#  u'210',
#  u'2100',
#  u'2102',
#  u'210amp',
#  u'210d',
#  u'210ft',
#  u'210in',
#  u'211',
#  u'211cc',
#  u'212',
#  u'212cc',
#  u'212ss',
#  u'214',
#  u'2149',
#  u'215',
#  u'2150mah',
#  u'216',
#  u'2160p',
#  u'216in',
#  u'2188in',
#  u'2191',
#  u'21a',
#  u'21ft',
#  u'21gal',
#  u'21in',
#  u'21mm',
#  u'21oz',
#  u'22',
#  u'220',
#  u'2200',
#  u'2200k',
#  u'2200lb',
#  u'2201',
#  u'220a',
#  u'220ft',
#  u'220in',
#  u'220k',
#  u'220lb',
#  u'220v',
#  u'2210',
#  u'222',
#  u'2222',
#  u'2230',
#  u'2234',
#  u'2240',
#  u'2246',
#  u'224c',
#  u'224in',
#  u'225',
#  u'2255',
#  u'2256',
#  u'2258',
#  u'225ft',
#  u'225lb',
#  u'2260',
#  u'227d',
#  u'228a',
#  u'22amp',
#  u'22cm',
#  u'22ft',
#  u'22gal',
#  u'22in',
#  u'22k',
#  u'22kw',
#  u'22mm',
#  u'22oz',
#  u'23',
#  u'230',
#  u'2300',
#  u'230a',
#  u'230b',
#  u'230m',
#  u'230mah',
#  u'230v',
#  u'231',
#  u'2310',
#  u'233',
#  u'2330',
#  u'234in',
#  u'236in',
#  u'237',
#  u'2375j',
#  u'238',
#  u'239',
#  u'23f',
#  u'23ft',
#  u'23g',
#  u'23gal',
#  u'23in',
#  u'23mm',
#  u'24',
#  u'240',
#  u'2400',
#  u'2406',
#  u'2409',
#  u'240b',
#  u'240d',
#  u'240in',
#  u'240oz',
#  u'240v',
#  u'243',
#  u'243in',
#  u'2448',
#  u'2449',
#  u'245',
#  u'2450',
#  u'247',
#  u'2483',
#  u'2484',
#  u'249',
#  u'2497',
#  u'24cm',
#  u'24f',
#  u'24ft',
#  u'24in',
#  u'24k',
#  u'24lb',
#  u'24oz',
#  u'24p',
#  u'24q',
#  u'24tpi',
#  u'25',
#  u'250',
#  u'2500',
#  u'2500k',
#  u'250e',
#  u'250f',
#  u'250ft',
#  u'250lb',
#  u'250s',
#  u'250v',
#  u'251',
#  u'254cc',
#  u'255',
#  u'2550kc',
#  u'2590',
#  u'25amp',
#  u'25cc',
#  u'25ft',
#  u'25gal',
#  u'25in',
#  u'25k',
#  u'25lb',
#  u'25mm',
#  u'25oz',
#  u'25w',
#  u'26',
#  u'260',
#  u'2600',
#  u'2600lb',
#  u'260b',
#  u'260c',
#  u'260e',
#  u'260in',
#  u'2610f',
#  u'262ft',
#  u'263in',
#  u'264',
#  u'264in',
#  u'265',
#  u'2650',
#  u'2656',
#  u'265ft',
#  u'266',
#  u'267',
#  u'268',
#  u'269',
#  u'26cc',
#  u'26ft',
#  u'26g',
#  u'26gal',
#  u'26in',
#  u'26lb',
#  u'26oz',
#  u'26w',
#  u'27',
#  u'270',
#  u'2700',
#  u'27000',
#  u'2700k',
#  u'270cc',
#  u'270lb',
#  u'2731',
#  u'2749',
#  u'275',
#  u'2751',
#  u'277',
#  u'277cc',
#  u'277v',
#  u'277vac',
#  u'2781',
#  u'279',
#  u'27_',
#  u'27cc',
#  u'27f',
#  u'27ft',
#  u'27gal',
#  u'27in',
#  u'27kw',
#  u'27lb',
#  u'27m',
#  u'27oz',
#  u'27sq',
#  u'28',
#  u'280',
#  u'2800',
#  u'2800k',
#  u'280e',
#  u'280f',
#  u'28125gal',
#  u'281ft',
#  u'282',
#  u'282ft',
#  u'283',
#  u'284',
#  u'285',
#  u'287',
#  u'287sf',
#  u'288',
#  u'288in',
#  u'28ft',
#  u'28gal',
#  u'28in',
#  u'28lb',
#  u'28oz',
#  ...]
